# %% [markdown]
# <a href="https://colab.research.google.com/github/VAjmeera/vanitha_ajmeera/blob/main/Untitled26.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data = pd.read_excel('Capstone_final_dataset.xlsx')
data.head()
# Out:
#    time0_year  first_tx   race  black SEX  age  above74  age_cat  ABIRATERONE  \
# 0        2017  ENZALUTA  White      0   M   70        0        3            0
# 1        2015  ABIRATER  White      0   M   68        0        2            1
# 2        2015  ABIRATER  White      0   M   71        0        3            1
# 3        2015  ABIRATER  White      0   M   79        1        3            1
# 4        2016  ABIRATER  White      0   M   90        1        5            1
#
#    enza  ...   a1c_cat  cindex_b_Romano  char_cat  Total_Elixhauser_Groups  \
# 0     1  ...   1. <5.6                2         1                        3
# 1     0  ...   1. <5.6                4         2                        7
# 2     0  ...   1. <5.6                3         1                        5
# 3     0  ...  4. >=7.2                7         3                       10
# 4     0  ...       NaN                3         1                        6
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5822 entries, 0 to 5821
# Data columns (total 32 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   time0_year                   5822 non-null   int64
#  1   first_tx                     5822 non-null   object
#  2   race                         5822 non-null   object
#  3   black                        5822 non-null   int64
#  4   SEX                          5822 non-null   object
#  5   age                          5822 non-null   int64
#  6   above74                      5822 non-null   int64
#  7   age_cat                      5822 non-null   int64
#  8   ABIRATERONE                  5822 non-null   int64
#  9   enza                         5822 non-null   int64
#  10  first_tx_last_day_Supply     5822 non-null   int64
#  11  days_bt_first_last_prescrib  5822 non-null   int64
#  12  first_tx_daysSupply_sum      5822 non-null   int64
# ...

# %%
data.describe()
# Out:
#         time0_year        black          age      above74      age_cat  \
# count  5822.000000  5822.000000  5822.000000  5822.000000  5822.000000
# mean   2015.607867     0.232051    75.225009     0.499485     3.074888
# std       0.902930     0.422178     9.054771     0.500043     0.998655
# min    2014.000000     0.000000    46.000000     0.000000     0.000000
# 25%    2015.000000     0.000000    68.000000     0.000000     2.000000
# 50%    2016.000000     0.000000    74.000000     0.000000     3.000000
# 75%    2016.000000     0.000000    83.000000     1.000000     4.000000
# max    2017.000000     1.000000    90.000000     1.000000     5.000000
#
#        ABIRATERONE         enza  first_tx_last_day_Supply  \
# count  5822.000000  5822.000000               5822.000000
# mean      0.569907     0.430093                 31.118516
# std       0.495131     0.495131                  9.311150
# min       0.000000     0.000000                  1.000000
# ...

# %%
import matplotlib.pyplot as plt
# Bar chart for first_tx (Treatment Type) by SEX (Gender)
treatment_by_gender = data.groupby(['first_tx', 'SEX']).size().unstack()

# Plotting the bar chart
treatment_by_gender.plot(kind='bar', stacked=True)
plt.title('Distribution of Treatment Type by Gender')
plt.xlabel('Treatment Type')
plt.ylabel('Count')
plt.legend(title='Gender')
plt.xticks(rotation=45)
plt.show()

# %%
# Pie chart for age category (age_cat)
age_cat_counts = data['age_cat'].value_counts()

# Plotting the pie chart
plt.figure(figsize=(6,6))
plt.pie(age_cat_counts, labels=age_cat_counts.index, autopct='%1.1f%%', startangle=90, colors=plt.cm.Paired.colors)
plt.title('Age Category Distribution')
plt.show()

# %%
# Scatter plot for all features (age, ABIRATERONE, enza)
plt.figure(figsize=(10, 6))
plt.scatter(data['age'], data['ABIRATERONE'], label='Abiraterone', alpha=0.6)
plt.scatter(data['age'], data['enza'], label='Enzalutamide', alpha=0.6)
plt.title('Scatter Plot: Age vs Abiraterone/Enzalutamide Treatments')
plt.xlabel('Age')
plt.ylabel('Treatment')
plt.legend()
plt.show()

# %%
# Box plot and histogram for two features: age and Total_Elixhauser_Groups
fig, axes = plt.subplots(2, 2, figsize=(14, 10))

# Box plot for age
axes[0, 0].boxplot(data['age'].dropna())
axes[0, 0].set_title('Box Plot of Age')
axes[0, 0].set_ylabel('Age')

# Box plot for Total Elixhauser Groups
axes[0, 1].boxplot(data['Total_Elixhauser_Groups'].dropna())
axes[0, 1].set_title('Box Plot of Total Elixhauser Groups')
axes[0, 1].set_ylabel('Total Elixhauser Groups')

# Histogram for age
axes[1, 0].hist(data['age'].dropna(), bins=10, color='skyblue', edgecolor='black')
axes[1, 0].set_title('Histogram of Age')
axes[1, 0].set_xlabel('Age')
axes[1, 0].set_ylabel('Frequency')

# Histogram for Total Elixhauser Groups
axes[1, 1].hist(data['Total_Elixhauser_Groups'].dropna(), bins=10, color='orange', edgecolor='black')
axes[1, 1].set_title('Histogram of Total Elixhauser Groups')
axes[1, 1].set_xlabel('Total Elixhauser Groups')
axes[1, 1].set_ylabel('Frequency')

plt.tight_layout()
plt.show()
